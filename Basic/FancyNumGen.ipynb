# %%
a = int(input())
b = int(input())

for i in range(a,b):
    if i % 19 == 0:
        print(i)
# Out:
# 1300
# 2999
# 1311
# 1330
# 1349
# 1368
# 1387
# 1406
# 1425
# 1444
# 1463
# 1482
# 1501
# 1520
# 1539
# 1558
# 1577
# 1596
# 1615
# 1634
# 1653
# 1672
# 1691
# 1710
# 1729
# 1748
# 1767
# 1786
# 1805
# 1824
# 1843
# 1862
# 1881
# 1900
# 1919
# 1938
# 1957
# 1976
# 1995
# 2014
# 2033
# 2052
# 2071
# 2090
# 2109
# 2128
# 2147
# 2166
# 2185
# 2204
# 2223
# 2242
# 2261
# 2280
# 2299
# 2318
# 2337
# 2356
# 2375
# 2394
# 2413
# 2432
# 2451
# 2470
# 2489
# 2508
# 2527
# 2546
# 2565
# 2584
# 2603
# 2622
# 2641
# 2660
# 2679
# 2698
# 2717
# 2736
# 2755
# 2774
# 2793
# 2812
# 2831
# 2850
# 2869
# 2888
# 2907
# 2926
# 2945
# 2964
# 2983
